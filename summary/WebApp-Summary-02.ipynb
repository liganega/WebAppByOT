# %% [markdown]
# # HTML 실습

# %% [markdown]
# ## h1, h2, h3 태그
#
# * 제목, 챕터 등에 사용
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web21.png", width=300>
# </td>
#
# </tr>
#
# </table>
# </p>

# %% [markdown]
# ## 의미가 잘 드러나는 웹 (Semantic Web)
#
# * 사람뿐만 아니라 웹브라우저 등의 기계에도 정보를 보다 더 잘 전달하도록 하는 태그들을 활용함.
# * CSS를 함께 사용할 때 중요 역할 수행
# * 다른 특별한 기능은 없음. 즉, 내용에 어떤 변화를 주지 않음.
# * 예제: `nav` 태그
#     * 탐색용 부분이라는 정보를 웹브라우 알려주는 태그
#     * nav = navigation
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web22.png", width=300>
# </td>
# <td>
# <img src="images/internet-web23.png", width=300>
# </td>
#
#
# </tr>
#
# </table>
# </p>
#
# * 예제: `header` 태그
#
#     * 내용의 간판 역할을 수행한다는 점을 드러냄.
#
# <tr>
# <td>
# <img src="images/internet-web24.png", width=300>
# </td>
#
# </tr>
#
# </table>
# </p>
#
#
# * 예제: `article` 태그
#
#     * 문서의 본문 영역 드러냄
# <tr>
# <td>
# <img src="images/internet-web25.png", width=300>
#
# </tr>
#
# </table>
# </p>
#
# * 완성 예제 코드:
#
# <tr>
# <td>
# <img src="images/internet-web26.png", width=300>
#
# </tr>
#
# </table>
# </p>

# %% [markdown]
# ## index.html 파일
#
# * 웹사이트의 대문 페이지 역할을 수행하는 특수한 파일
# * 특정 사이트의 메인 페이지를 방문할 경우 서버는 우선적으로 `index.html` 파일 내용을 전달해줌.
# * 대문 역할에 해당하는 내용만 남겨 두고 다른 내용은 내용 별로 분리하여 여러 개의 html 파일을 생성함.
# * 대신에 `index.html` 파일에 다른 페이지에 해당하는 **링크**를 작성해야 함.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web27.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * 앞서 배운 태그들을 활용하여 각각의 페이지의 내용을 담은 html 파일을 생성해야 함.
#     그렇지 않으면 링크를 눌렀을 때 오류 발생.
#
# * 위 그림에 포함된 코드의 경우 아래 세 개의 파일이 추가로 생성되야 함.
#     * `page_html.html`: JavaScriptf란 주제 관련 내용
#     * `page_vc.html`: 변수와 상수 관련 내용
#     * `page_op.html`: 연산자 관련 내용
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web28.png", width=200>
# </td>
# <td>
# <img src="images/internet-web29.png", width=200>
# </td>
# <td>
# <img src="images/internet-web30.png", width=200>
# </td>
# </tr>
#
# </table>
# </p>
#
# * header에도 링크를 주고 완성하면 다음과 같다.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web31.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * **주의사항:**
#     * 이렇게 하면 다른 파일에서도 header 부분을 수정해야 불편함이 발생한다.
#         몇 개 정도는 가능하지만 수 백, 수 천 개의 페이지를 수정하는 일은 불가능하다.
#         따라서 다른 기술이 요구된다.
#
#     * 앞으로 CSS, Javascript, php 언어와 코딩 디자인 요령 등을 터득하면서 보다 효율적이면서
#         멋있는 웹디자인을 구현하는 방법을 터득하게 될 것이다.

# %% [markdown]
# # CSS 이론
#
# * CSS = Cascading Style Sheet
# * 스타일을 꾸며주는 언어
# * html과는 완전히 다른 언어이지만, html과는 별개로 사용될 수 없음
# * `head` 태그 안에서 `style` 태그로 감싸임

# %% [markdown]
# ## CSS 기초

# %% [markdown]
# * 예제: h1 태그의 색상을 빨강으로 바꿀 때
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web32.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * 위 예제에서 `h1`은 **선택자**라 불리고 나머지 부분은 **서술**이라고 불린다.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web33.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * 서술에는 `color` 속성 이외에 다양한 속성들이 있다.
#     * `font-size`: 글자 크기. 픽셀(px) 단위로 설정
#     * `text-decoration`: 밑줄 긋기 등 설정
#     * `border`: 상자로 감싸기 옵션
#     * 등등
#     * 속성은 세미콜론(`;`)으로 구분됨.
#
# * 선택자는 여러 개를 동시에 또는 따로 따로 지정할 수 있다.
#     * 동시 선택: h1, h2 { 속성들 }
#         * 쉼표에 주의
#
# * 중첩 선택자 사용 가능
#     * 예를 들어, header 태그 안의 h1 태그에만 속성 정할 때: header h1 { 속성들 }
#         * 쉼표 없음
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web34.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>

# %% [markdown]
# ## CSS 심화: 박스모델

# %% [markdown]
# * 리스트의 각 항목 별로 스타일 꾸미기
#     * 태그선택자 사용
#         * style 태그에서: 샵(`#`) 기호 사용
#         * 본문에서는 `id` 속성 활용
#
#     * 속성을 지정하는 방식은 기타 속성 설정과 동일
#     * 아래 사진은 상자그리기의 다양한 속성을 설정하는 내용을 보여줌.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web35.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * 박스모델에서 상자그리기의 주요 속성은 아래 그림에서 확인할 수 있다.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web36.png", width=300>
# </td>
# </tr>
#
# </table>
# </p>
#
# * 크롬 브라우저의 요소검사 기능을 이용하여 박스모델의 설정을 확인 및 연습할 수 있다.
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web37.png", width=300>
# </td>
# <td>
# <img src="images/internet-web38.png", width=300>
# </td>
#
# </tr>
#
# </table>
# </p>

# %% [markdown]
# ## CSS 심화: float 기능

# %% [markdown]
# * 이미지 추가할 때 유용한 기능
# * `img` 태그선택자 속성 중에서 `float` 속성을 지정하면 이미지와 본문 내용을 적절하게 꾸며줄 수 있다.
# * `float` 속성 값: `left`와 `right`
#
# <p>
# <table cellspacing="20">
#
# <tr>
# <td>
# <img src="images/internet-web39.png", width=300>
# </td>
#
# </tr>
#
# </table>
# </p>

# %% [markdown]
# # CSS 실습
