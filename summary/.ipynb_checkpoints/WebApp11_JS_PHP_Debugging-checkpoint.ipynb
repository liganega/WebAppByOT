# %% [markdown]
# # 디버깅

# %% [markdown]
# ## JS 에러 찾기
#
# 크롬 브라우저의 "자바스크립트 콘솔 활용한다.
# 예를 들어, 오타가 있는 것을 찾아 내는 과정은 다음과 같다.
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web72.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web73.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web74.png", width=600>
# </td>
# </tr>
# </table>
# </p>

# %% [markdown]
# ## PHP 에러 찾기
#
# 크롬 브라우저의 자바스크립트 콘솔을 활용한다.
# 예를 들어, php 코드를 제대로 닫지 못한 경우 아래와 같이 확인한다.
#
# * 방법 1: 웹서버의 `php/apach2/logs/error.log` 파일에서 확인
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web75.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web76.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web77.png", width=600>
# </td>
# </tr>
# </table>
# </p>

# %% [markdown]
# * 방법 2: 웹브라우저에 직접 오류를 뜨게 해서 확인
#     * 웹서버의 `php/etc/php.ini` 파일에서 `display_errors`의 값을 `Off`에서 `On`으로 변경
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web78.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web79.png", width=600>
# </td>
# </tr>
# </table>
# </p>
#
# <p>
# <table cellspacing="20">
# <tr>
# <td>
# <img src="images/internet-web80.png", width=600>
# </td>
# </tr>
# </table>
# </p>
